# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei']   # 用黑体显示中文
plt.rcParams['axes.unicode_minus']=False     # 正常显示负号

# %%
path = 'input/'
train = pd.read_csv(path+'first_round_training_data.csv')
test = pd.read_csv(path+'first_round_testing_data.csv')
submit = pd.read_csv(path+'submit_example.csv')

# %%
sub = submit.copy()
sub['Excellent ratio'] = 0.11

sub['Good ratio'] = 0.16
sub['Pass ratio'] = 0.24
sub['Fail ratio'] = 0.09

# %%
train.head()
# Out:
#    Parameter1  Parameter2  Parameter3  Parameter4  Parameter5  Parameter6  \
# 0    0.001660    0.591013  147.608373   38.186345    0.000421    0.000612
# 1    1.601749    0.015052    0.035864   51.130326    0.000909    0.002397
# 2    0.098039   69.233685    0.080920    0.112265    0.000909    0.001972
# 3   18.181860    0.047325    0.018061    1.098102    0.000909    0.002397
# 4    0.012085    0.008749    0.005509  524.327396    0.000909    0.002397
#
#     Parameter7  Parameter8  Parameter9  Parameter10      ...        \
# 0  2286.523413    0.035407    0.593081     1.010385      ...
# 1  2286.523413    0.035407    0.593081     1.010385      ...
# 2  2286.523413    0.035407    0.593081     1.010385      ...
# 3  2286.523413    0.035407    0.593081     1.010385      ...
# 4  2286.523413    0.035407    0.593081     1.010385      ...
#
#    Attribute2  Attribute3  Attribute4  Attribute5    Attribute6  Attribute7  \
# ...

# %%
test.head()
# Out:
#    Group  Parameter1  Parameter10  Parameter2    Parameter3    Parameter4  \
# 0      0    0.235279     0.195680    0.351488      0.186814      0.086456
# 1      0    0.043799     0.523976   32.590688      0.886285     29.702490
# 2      0   21.466737     0.523976   11.847792  79499.554454  13544.605343
# 3      0    0.703795     0.010192    0.018080    317.015599     38.087562
# 4      0   10.447960     0.010192   15.983891      0.996049     16.715690
#
#    Parameter5  Parameter6  Parameter7  Parameter8  Parameter9
# 0    1.434060    1.230409    0.038483    2.931083    2.005852
# 1    0.027434    0.016852    0.600827    0.118077  887.611257
# 2    0.027434    0.016852    0.600827    0.118077  887.611257
# 3    0.428092    0.314162    0.038483   17.850021    0.051850
# 4    0.477823    0.464037    0.038483   17.850021    0.051850

# %%
train.groupby(['Quality_label'])['Parameter1'].size()
# Out:
# Quality_label
# Excellent    1107
# Fail          892
# Good         1584
# Pass         2417
# Name: Parameter1, dtype: int64

# %%
sub.head()
# Out:
#    Group  Excellent ratio  Good ratio  Pass ratio  Fail ratio
# 0      0             0.11        0.16        0.24        0.09
# 1      1             0.11        0.16        0.24        0.09
# 2      2             0.11        0.16        0.24        0.09
# 3      3             0.11        0.16        0.24        0.09
# 4      4             0.11        0.16        0.24        0.09

# %%
sub.to_csv(path+'sub1.csv',header=True,index=False)

# %%
colums = train.columns

col_A = colums[:10]
col_B = colums[11:20]

# %%
fig = plt.figure()  # 创建画布
ax = plt.subplot()  # 创建作图区域
plt.ylim(0,100)
plt.xticks(rotation=270)
ax.boxplot(x=train[colums[:10]].values,labels=colums[:10])

plt.show()

# %%
fig = plt.figure()  # 创建画布
ax = plt.subplot()  # 创建作图区域
plt.ylim(0,100)
plt.xticks(rotation=270)
ax.boxplot(x=test[colums[:10]].values,labels=colums[:10])
# ax.boxplot(x=train['Parameter1'].values,labels=['Parameter1'])
# plt.plot(train['Parameter1'])
plt.show()

# %%
train.describe()
# Out:
#           Parameter1    Parameter2     Parameter3     Parameter4  \
# count    6000.000000  6.000000e+03    6000.000000    6000.000000
# mean      485.198954  1.952379e+03     406.348529     189.205842
# std     11401.971393  5.419588e+04   12018.898941    2621.779049
# min         0.000003  1.683797e-07       0.000005       0.000002
# 25%         0.088221  4.765771e-02       0.102304       0.118314
# 50%         1.050304  9.405962e-01       1.044908       1.068467
# 75%        10.938565  1.569199e+01      10.665397       9.902064
# max    713682.207601  3.034568e+06  864530.632179  139767.494732
#
#          Parameter5    Parameter6    Parameter7    Parameter8    Parameter9  \
# count  6.000000e+03  6.000000e+03   6000.000000   6000.000000  6.000000e+03
# mean   5.868163e+00  5.598597e+00    272.300821     22.133231  5.823664e+04
# std    8.631865e+00  7.686898e+00   2027.460514    302.172768  3.173068e+06
# ...
